# %% [markdown]
# # 🚀 MobileNetV3 Transfer Learning — Version Optimisée GPU

# %%
# ── Cellule 1 : Vérification GPU ──────────────────────────────────────────────
import torch
import subprocess

print('=' * 60)
print('🔍  VÉRIFICATION GPU')
print('=' * 60)

cuda_ok = torch.cuda.is_available()
print(f'  CUDA disponible         : {cuda_ok}')

if cuda_ok:
    print(f'  Nom du GPU              : {torch.cuda.get_device_name(0)}')
    print(f'  Mémoire totale          : {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB')
    print(f'  CUDA version            : {torch.version.cuda}')
    print(f'  cuDNN version           : {torch.backends.cudnn.version()}')
    # Active cuDNN benchmark pour choisir l'algo convolution le plus rapide
    torch.backends.cudnn.benchmark = True
    torch.backends.cudnn.deterministic = False
    print('  cuDNN benchmark         : ACTIVÉ ✅')
else:
    print('  ⚠️  Aucun GPU détecté — entraînement sur CPU (très lent)')

print('=' * 60)
# Out:
# ============================================================
# 🔍  VÉRIFICATION GPU
# ============================================================
#   CUDA disponible         : True
#   Nom du GPU              : Tesla T4
#   Mémoire totale          : 15.64 GB
#   CUDA version            : 12.8
#   cuDNN version           : 91002
#   cuDNN benchmark         : ACTIVÉ ✅
# ============================================================

# %%
# ── Cellule 2 : Montage Google Drive ──────────────────────────────────────────
from google.colab import drive
import time

print('=' * 60)
print('📂  MONTAGE GOOGLE DRIVE')
print('=' * 60)

t0 = time.time()
drive.mount('/content/drive')
print(f'  ✅ Drive monté en {time.time()-t0:.1f}s')
print('=' * 60)
# Out:
# ============================================================
# 📂  MONTAGE GOOGLE DRIVE
# ============================================================
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#   ✅ Drive monté en 1.9s
# ============================================================

# %%
# ── Cellule 3 : Copie dataset en local (I/O rapide) ───────────────────────────
import shutil, os, time

print('=' * 60)
print('📁  COPIE DU DATASET EN LOCAL')
print('=' * 60)

src  = '/content/drive/MyDrive/splitdataset'
dst  = '/content/dataset'

if os.path.exists(dst):
    print(f'  Dossier {dst} déjà présent — copie ignorée.')
else:
    print(f'  Source  : {src}')
    print(f'  Dest    : {dst}')
    print('  Copie en cours...')
    t0 = time.time()
    shutil.copytree(src, dst)
    print(f'  ✅ Copie terminée en {time.time()-t0:.1f}s')

# Compter les images par split
data_dir = dst
for split in ['train', 'val']:
    split_path = os.path.join(data_dir, split)
    if os.path.exists(split_path):
        classes = os.listdir(split_path)
        n_imgs  = sum(len(os.listdir(os.path.join(split_path, c))) for c in classes)
        print(f'  {split:5s} → {len(classes)} classes | {n_imgs} images')

print('=' * 60)
# Out:
# ============================================================
# 📁  COPIE DU DATASET EN LOCAL
# ============================================================
#   Source  : /content/drive/MyDrive/splitdataset
#   Dest    : /content/dataset
#   Copie en cours...
#   ✅ Copie terminée en 1853.4s
#   train → 6 classes | 42001 images
#   val   → 6 classes | 9016 images
# ============================================================

# %%
# ── Cellule 4 : Data pipeline — Augmentation renforcée ───────────────────────
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import multiprocessing

print('=' * 60)
print('⚙️   CONFIGURATION DATA PIPELINE (Augmentation renforcée)')
print('=' * 60)

NUM_WORKERS = min(multiprocessing.cpu_count(), 8)
BATCH_SIZE  = 64
PIN_MEMORY  = True
PREFETCH    = 4

print(f'  Batch size              : {BATCH_SIZE}')
print(f'  Num workers             : {NUM_WORKERS}')
print(f'  Pin memory              : {PIN_MEMORY}')
print(f'  Prefetch factor         : {PREFETCH}')

# ── Augmentation renforcée (Amélioration #3) ──────────────────────────────────
train_transforms = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomCrop(224),                          # crop aléatoire
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),                     # NOUVEAU
    transforms.RandomRotation(30),                       # rotation plus forte
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1),  # NOUVEAU hue
    transforms.RandomPerspective(distortion_scale=0.2, p=0.3),  # NOUVEAU
    transforms.RandomGrayscale(p=0.05),                  # NOUVEAU
    transforms.GaussianBlur(kernel_size=3, sigma=(0.1, 1.5)),   # NOUVEAU
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    transforms.RandomErasing(p=0.2, scale=(0.02, 0.1)),  # NOUVEAU : masque aléatoire
])

val_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_dataset = datasets.ImageFolder(f'{data_dir}/train', transform=train_transforms)
val_dataset   = datasets.ImageFolder(f'{data_dir}/val',   transform=val_transforms)

train_loader = DataLoader(
    train_dataset, batch_size=BATCH_SIZE, shuffle=True,
    num_workers=NUM_WORKERS, pin_memory=PIN_MEMORY,
    prefetch_factor=PREFETCH, persistent_workers=True
)
val_loader = DataLoader(
    val_dataset, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=NUM_WORKERS, pin_memory=PIN_MEMORY,
    prefetch_factor=PREFETCH, persistent_workers=True
)

print(f'  Classes ({len(train_dataset.classes)})            : {train_dataset.classes}')
print(f'  Batches train           : {len(train_loader)}')
print(f'  Batches val             : {len(val_loader)}')
print('  Augmentations NOUVELLES : RandomVerticalFlip, Perspective, GaussianBlur, RandomErasing, hue')
print('  ✅ DataLoaders prêts')
print('=' * 60)
# Out:
# ============================================================
# ⚙️   CONFIGURATION DATA PIPELINE (Augmentation renforcée)
# ============================================================
#   Batch size              : 64
#   Num workers             : 2
#   Pin memory              : True
#   Prefetch factor         : 4
#   Classes (6)            : ['Anthracnose', 'Ash weevil', 'Canker', 'Greening', 'Healthy', 'Leaf miner']
#   Batches train           : 657
#   Batches val             : 141
#   Augmentations NOUVELLES : RandomVerticalFlip, Perspective, GaussianBlur, RandomErasing, hue
#   ✅ DataLoaders prêts
# ============================================================

# %%
# ── Cellule 5 : Modèle MobileNetV3 — Fine-tuning (Améliorations #1 & #2) ─────
import torchvision.models as models
import torch.nn as nn

print('=' * 60)
print('🧠  CHARGEMENT MODÈLE MOBILENETV3-LARGE (Fine-tuning)')
print('=' * 60)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'  Device                  : {device}')

model = models.mobilenet_v3_large(weights='IMAGENET1K_V1')

# ── Amélioration #1 : Gel de TOUTES les couches d'abord ───────────────────────
for param in model.parameters():
    param.requires_grad = False

# ── Amélioration #1 : Dégel des 3 derniers blocs de features + classifier ─────
# MobileNetV3-Large a 16 blocs dans model.features (indices 0-15)
# On dégèle les blocs 13, 14, 15 + le classifier
for param in model.features[13:].parameters():
    param.requires_grad = True
for param in model.classifier.parameters():
    param.requires_grad = True

# ── Remplacement du classifier final (6 classes) ──────────────────────────────
num_classes = len(train_dataset.classes)
in_features = model.classifier[-1].in_features
model.classifier[-1] = nn.Linear(in_features, num_classes)

# Compte les paramètres
total_params     = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

model = model.to(device)

print(f'  Paramètres totaux       : {total_params:,}')
print(f'  Paramètres entraînables : {trainable_params:,}  (vs 7 686 avant)')
print(f'  Nouvelles sorties       : {num_classes} classes')
print(f'  Couches dégelées        : features[13:] + classifier')

if torch.cuda.is_available():
    mem_alloc = torch.cuda.memory_allocated(0) / 1e6
    print(f'  VRAM après chargement   : {mem_alloc:.1f} MB')

print('  ✅ Modèle chargé sur', device)
print('=' * 60)
# Out:
# ============================================================
# 🧠  CHARGEMENT MODÈLE MOBILENETV3-LARGE (Fine-tuning)
# ============================================================
#   Device                  : cuda
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_large-8738ca79.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_large-8738ca79.pth
# 100%|██████████| 21.1M/21.1M [00:00<00:00, 150MB/s]
#   Paramètres totaux       : 4,209,718
#   Paramètres entraînables : 3,417,230  (vs 7 686 avant)
#   Nouvelles sorties       : 6 classes
#   Couches dégelées        : features[13:] + classifier
#   VRAM après chargement   : 17.0 MB
#   ✅ Modèle chargé sur cuda
# ============================================================

# %%
# ── Cellule 6 : Fonctions train / eval avec AMP (mixed precision) ─────────────
from torch.cuda.amp import autocast, GradScaler
import time

scaler = GradScaler()   # Gère les gradients en float16 pour économiser la VRAM

def gpu_stats():
    """Retourne une chaîne avec l'utilisation GPU actuelle."""
    if not torch.cuda.is_available():
        return ''
    alloc    = torch.cuda.memory_allocated(0)  / 1e6
    reserved = torch.cuda.memory_reserved(0)   / 1e6
    return f'VRAM {alloc:.0f}/{reserved:.0f} MB'


def train_one_epoch(model, loader, optimizer, criterion, epoch, total_epochs):
    model.train()
    total_loss  = 0.0
    correct     = 0
    total       = 0
    t_start     = time.time()

    for batch_idx, (images, labels) in enumerate(loader):
        # Transfert non-bloquant CPU→GPU
        images = images.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)   # Plus rapide que zero_grad()

        # ── Mixed Precision (float16) ──
        with autocast():
            outputs = model(images)
            loss    = criterion(outputs, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        total_loss += loss.item()
        preds       = outputs.argmax(1)
        correct    += (preds == labels).sum().item()
        total      += labels.size(0)

        # Print progression toutes les 10 batches
        if (batch_idx + 1) % 10 == 0 or (batch_idx + 1) == len(loader):
            elapsed    = time.time() - t_start
            imgs_per_s = (batch_idx + 1) * images.size(0) / elapsed
            print(
                f'    Epoch {epoch}/{total_epochs}'
                f' | Batch {batch_idx+1:3d}/{len(loader)}'
                f' | Loss {total_loss/(batch_idx+1):.4f}'
                f' | Train Acc {correct/total:.3f}'
                f' | {imgs_per_s:.0f} img/s'
                f' | {gpu_stats()}'
            )

    epoch_time = time.time() - t_start
    return total_loss / len(loader), correct / total, epoch_time


def evaluate(model, loader):
    model.eval()
    correct = 0
    total   = 0
    t_start = time.time()

    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)
            with autocast():
                outputs = model(images)
            preds    = outputs.argmax(1)
            correct += (preds == labels).sum().item()
            total   += labels.size(0)

    val_time = time.time() - t_start
    return correct / total, val_time

print('  ✅ Fonctions train/eval définies avec AMP (float16)')
# Out:
#   ✅ Fonctions train/eval définies avec AMP (float16)
# /tmp/ipykernel_4893/2171682761.py:5: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()   # Gère les gradients en float16 pour économiser la VRAM

# %%
# ── Cellule 7 : Entraînement — 20 epochs, lr=1e-4, deux groupes de LR ─────────
import torch.optim as optim

EPOCHS = 20

# ── Amélioration #6 : Learning rate réduit à 1e-4 ─────────────────────────────
# Deux groupes de paramètres :
#   • Couches dégelées (features[13:]) : lr faible pour ne pas détruire les poids pré-entraînés
#   • Classifier (nouvelle couche)     : lr un peu plus élevé car initialisé aléatoirement
LR_BACKBONE    = 1e-4   # features dégelées
LR_CLASSIFIER  = 3e-4   # tête de classification

backbone_params   = list(model.features[13:].parameters())
classifier_params = list(model.classifier.parameters())

optimizer = optim.Adam([
    {'params': backbone_params,   'lr': LR_BACKBONE},
    {'params': classifier_params, 'lr': LR_CLASSIFIER},
])

# CosineAnnealingLR sur 20 epochs — descend doucement le LR
scheduler  = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS, eta_min=1e-6)

# Label smoothing conservé
criterion  = nn.CrossEntropyLoss(label_smoothing=0.1)

history    = []
best_acc   = 0.0
total_t    = time.time()

print('=' * 60)
print('🏋️   DÉMARRAGE ENTRAÎNEMENT (version améliorée)')
print('=' * 60)
print(f'  Epochs                  : {EPOCHS}')
print(f'  LR backbone (features)  : {LR_BACKBONE}')
print(f'  LR classifier           : {LR_CLASSIFIER}')
print(f'  Scheduler               : CosineAnnealingLR (eta_min=1e-6)')
print(f'  Loss                    : CrossEntropy + label smoothing 0.1')
print(f'  Mixed Precision (AMP)   : ✅ activé')
print(f'  Fine-tuning             : features[13:] + classifier dégelés')
print('=' * 60)

for epoch in range(1, EPOCHS + 1):
    lr_bb  = optimizer.param_groups[0]['lr']
    lr_cls = optimizer.param_groups[1]['lr']
    print(f'\n📌 Epoch {epoch}/{EPOCHS}  —  LR backbone={lr_bb:.2e} | LR classifier={lr_cls:.2e}')
    print(f'  ▶ Phase TRAIN ...')

    train_loss, train_acc, t_train = train_one_epoch(
        model, train_loader, optimizer, criterion, epoch, EPOCHS
    )

    print(f'  ▶ Phase VAL ...')
    val_acc, t_val = evaluate(model, val_loader)

    scheduler.step()

    # Sauvegarde du meilleur modèle
    if val_acc > best_acc:
        best_acc = val_acc
        torch.save(model.state_dict(), '/content/best_model_finetuned.pth')
        best_tag = '  ⭐ NOUVEAU MEILLEUR MODÈLE SAUVEGARDÉ'
    else:
        best_tag = ''

    history.append({'epoch': epoch, 'loss': train_loss,
                    'train_acc': train_acc, 'val_acc': val_acc})

    if torch.cuda.is_available():
        vram_peak = torch.cuda.max_memory_allocated(0) / 1e6
        torch.cuda.reset_peak_memory_stats(0)
        vram_str  = f'  | VRAM peak {vram_peak:.0f} MB'
    else:
        vram_str = ''

    print(
        f'\n  ✅ Epoch {epoch:2d} résumé'
        f' | Loss {train_loss:.4f}'
        f' | Train Acc {train_acc:.4f}'
        f' | Val Acc {val_acc:.4f}'
        f' | Train {t_train:.1f}s'
        f' | Val {t_val:.1f}s'
        f'{vram_str}'
        f'{best_tag}'
    )

print('\n' + '=' * 60)
print(f'  🏁 Entraînement terminé en {time.time()-total_t:.1f}s')
print(f'  🏆 Meilleure Val Acc : {best_acc:.4f}')
print(f'  💾 Meilleur modèle  : /content/best_model_finetuned.pth')
print('=' * 60)
# Out:
# ============================================================
# 🏋️   DÉMARRAGE ENTRAÎNEMENT (version améliorée)
# ============================================================
#   Epochs                  : 20
#   LR backbone (features)  : 0.0001
#   LR classifier           : 0.0003
#   Scheduler               : CosineAnnealingLR (eta_min=1e-6)
#   Loss                    : CrossEntropy + label smoothing 0.1
#   Mixed Precision (AMP)   : ✅ activé
#   Fine-tuning             : features[13:] + classifier dégelés
# ============================================================
#
# 📌 Epoch 1/20  —  LR backbone=1.00e-04 | LR classifier=3.00e-04
#   ▶ Phase TRAIN ...
# /tmp/ipykernel_4893/2171682761.py:31: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
#     Epoch 1/20 | Batch  10/657 | Loss 1.5897 | Train Acc 0.388 | 20 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch  20/657 | Loss 1.4504 | Train Acc 0.466 | 33 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch  30/657 | Loss 1.3433 | Train Acc 0.521 | 40 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch  40/657 | Loss 1.2772 | Train Acc 0.556 | 47 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch  50/657 | Loss 1.2330 | Train Acc 0.579 | 50 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch  60/657 | Loss 1.1976 | Train Acc 0.599 | 55 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch  70/657 | Loss 1.1646 | Train Acc 0.618 | 57 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch  80/657 | Loss 1.1411 | Train Acc 0.634 | 61 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch  90/657 | Loss 1.1212 | Train Acc 0.647 | 62 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 100/657 | Loss 1.1011 | Train Acc 0.658 | 64 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 110/657 | Loss 1.0857 | Train Acc 0.667 | 66 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 120/657 | Loss 1.0721 | Train Acc 0.675 | 67 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 130/657 | Loss 1.0594 | Train Acc 0.682 | 68 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 140/657 | Loss 1.0485 | Train Acc 0.688 | 70 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 150/657 | Loss 1.0368 | Train Acc 0.694 | 70 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 160/657 | Loss 1.0288 | Train Acc 0.698 | 72 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 170/657 | Loss 1.0204 | Train Acc 0.703 | 72 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 180/657 | Loss 1.0131 | Train Acc 0.707 | 73 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 190/657 | Loss 1.0066 | Train Acc 0.709 | 73 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 200/657 | Loss 1.0000 | Train Acc 0.714 | 74 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 210/657 | Loss 0.9932 | Train Acc 0.718 | 75 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 220/657 | Loss 0.9891 | Train Acc 0.720 | 75 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 230/657 | Loss 0.9821 | Train Acc 0.724 | 76 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 240/657 | Loss 0.9752 | Train Acc 0.728 | 76 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 250/657 | Loss 0.9702 | Train Acc 0.731 | 77 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 260/657 | Loss 0.9654 | Train Acc 0.733 | 77 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 270/657 | Loss 0.9599 | Train Acc 0.736 | 77 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 280/657 | Loss 0.9542 | Train Acc 0.739 | 78 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 290/657 | Loss 0.9502 | Train Acc 0.740 | 78 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 300/657 | Loss 0.9454 | Train Acc 0.743 | 78 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 310/657 | Loss 0.9411 | Train Acc 0.745 | 79 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 320/657 | Loss 0.9375 | Train Acc 0.747 | 79 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 330/657 | Loss 0.9335 | Train Acc 0.750 | 79 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 340/657 | Loss 0.9295 | Train Acc 0.752 | 79 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 350/657 | Loss 0.9265 | Train Acc 0.753 | 80 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 360/657 | Loss 0.9225 | Train Acc 0.756 | 80 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 370/657 | Loss 0.9187 | Train Acc 0.758 | 80 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 380/657 | Loss 0.9153 | Train Acc 0.760 | 80 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 390/657 | Loss 0.9122 | Train Acc 0.762 | 81 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 400/657 | Loss 0.9097 | Train Acc 0.763 | 81 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 410/657 | Loss 0.9067 | Train Acc 0.765 | 81 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 420/657 | Loss 0.9042 | Train Acc 0.766 | 81 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 430/657 | Loss 0.9010 | Train Acc 0.768 | 81 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 440/657 | Loss 0.8974 | Train Acc 0.770 | 81 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 450/657 | Loss 0.8949 | Train Acc 0.771 | 81 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 460/657 | Loss 0.8918 | Train Acc 0.773 | 81 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 470/657 | Loss 0.8893 | Train Acc 0.775 | 82 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 480/657 | Loss 0.8875 | Train Acc 0.776 | 82 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 490/657 | Loss 0.8844 | Train Acc 0.777 | 82 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 500/657 | Loss 0.8814 | Train Acc 0.779 | 82 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 510/657 | Loss 0.8787 | Train Acc 0.780 | 82 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 520/657 | Loss 0.8759 | Train Acc 0.782 | 82 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 530/657 | Loss 0.8734 | Train Acc 0.783 | 82 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 540/657 | Loss 0.8712 | Train Acc 0.784 | 82 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 550/657 | Loss 0.8694 | Train Acc 0.785 | 82 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 560/657 | Loss 0.8672 | Train Acc 0.786 | 82 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 570/657 | Loss 0.8650 | Train Acc 0.788 | 83 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 580/657 | Loss 0.8626 | Train Acc 0.789 | 83 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 590/657 | Loss 0.8599 | Train Acc 0.791 | 83 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 600/657 | Loss 0.8576 | Train Acc 0.792 | 83 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 610/657 | Loss 0.8554 | Train Acc 0.793 | 83 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 620/657 | Loss 0.8530 | Train Acc 0.794 | 83 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 630/657 | Loss 0.8508 | Train Acc 0.796 | 83 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 640/657 | Loss 0.8492 | Train Acc 0.796 | 83 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 650/657 | Loss 0.8474 | Train Acc 0.797 | 83 img/s | VRAM 115/526 MB
#     Epoch 1/20 | Batch 657/657 | Loss 0.8462 | Train Acc 0.798 | 21 img/s | VRAM 86/151 MB
#   ▶ Phase VAL ...
# /tmp/ipykernel_4893/2171682761.py:71: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
#   ✅ Epoch  1 résumé | Loss 0.8462 | Train Acc 0.7980 | Val Acc 0.8578 | Train 522.0s | Val 25.4s  | VRAM peak 770 MB  ⭐ NOUVEAU MEILLEUR MODÈLE SAUVEGARDÉ
#
# 📌 Epoch 2/20  —  LR backbone=9.94e-05 | LR classifier=2.98e-04
#   ▶ Phase TRAIN ...
#     Epoch 2/20 | Batch  10/657 | Loss 0.7445 | Train Acc 0.844 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch  20/657 | Loss 0.7327 | Train Acc 0.855 | 87 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch  30/657 | Loss 0.7212 | Train Acc 0.861 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch  40/657 | Loss 0.7220 | Train Acc 0.862 | 89 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch  50/657 | Loss 0.7217 | Train Acc 0.860 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch  60/657 | Loss 0.7143 | Train Acc 0.866 | 90 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch  70/657 | Loss 0.7134 | Train Acc 0.867 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch  80/657 | Loss 0.7100 | Train Acc 0.869 | 90 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch  90/657 | Loss 0.7081 | Train Acc 0.870 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 100/657 | Loss 0.7090 | Train Acc 0.869 | 89 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 110/657 | Loss 0.7097 | Train Acc 0.868 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 120/657 | Loss 0.7073 | Train Acc 0.869 | 89 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 130/657 | Loss 0.7082 | Train Acc 0.869 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 140/657 | Loss 0.7101 | Train Acc 0.868 | 89 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 150/657 | Loss 0.7115 | Train Acc 0.867 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 160/657 | Loss 0.7113 | Train Acc 0.867 | 89 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 170/657 | Loss 0.7102 | Train Acc 0.869 | 89 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 180/657 | Loss 0.7080 | Train Acc 0.871 | 89 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 190/657 | Loss 0.7067 | Train Acc 0.872 | 89 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 200/657 | Loss 0.7051 | Train Acc 0.873 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 210/657 | Loss 0.7028 | Train Acc 0.874 | 89 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 220/657 | Loss 0.7021 | Train Acc 0.874 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 230/657 | Loss 0.7000 | Train Acc 0.875 | 89 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 240/657 | Loss 0.6999 | Train Acc 0.876 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 250/657 | Loss 0.6987 | Train Acc 0.876 | 89 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 260/657 | Loss 0.6978 | Train Acc 0.877 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 270/657 | Loss 0.6974 | Train Acc 0.877 | 89 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 280/657 | Loss 0.6971 | Train Acc 0.878 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 290/657 | Loss 0.6964 | Train Acc 0.878 | 89 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 300/657 | Loss 0.6964 | Train Acc 0.878 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 310/657 | Loss 0.6950 | Train Acc 0.879 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 320/657 | Loss 0.6940 | Train Acc 0.880 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 330/657 | Loss 0.6937 | Train Acc 0.880 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 340/657 | Loss 0.6944 | Train Acc 0.880 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 350/657 | Loss 0.6937 | Train Acc 0.880 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 360/657 | Loss 0.6929 | Train Acc 0.880 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 370/657 | Loss 0.6926 | Train Acc 0.880 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 380/657 | Loss 0.6923 | Train Acc 0.880 | 89 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 390/657 | Loss 0.6915 | Train Acc 0.881 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 400/657 | Loss 0.6903 | Train Acc 0.881 | 89 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 410/657 | Loss 0.6895 | Train Acc 0.882 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 420/657 | Loss 0.6885 | Train Acc 0.882 | 89 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 430/657 | Loss 0.6885 | Train Acc 0.882 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 440/657 | Loss 0.6875 | Train Acc 0.882 | 89 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 450/657 | Loss 0.6862 | Train Acc 0.883 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 460/657 | Loss 0.6863 | Train Acc 0.883 | 89 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 470/657 | Loss 0.6852 | Train Acc 0.884 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 480/657 | Loss 0.6844 | Train Acc 0.884 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 490/657 | Loss 0.6841 | Train Acc 0.884 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 500/657 | Loss 0.6838 | Train Acc 0.884 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 510/657 | Loss 0.6831 | Train Acc 0.884 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 520/657 | Loss 0.6825 | Train Acc 0.885 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 530/657 | Loss 0.6819 | Train Acc 0.885 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 540/657 | Loss 0.6816 | Train Acc 0.885 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 550/657 | Loss 0.6809 | Train Acc 0.886 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 560/657 | Loss 0.6798 | Train Acc 0.886 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 570/657 | Loss 0.6791 | Train Acc 0.886 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 580/657 | Loss 0.6786 | Train Acc 0.886 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 590/657 | Loss 0.6776 | Train Acc 0.887 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 600/657 | Loss 0.6771 | Train Acc 0.887 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 610/657 | Loss 0.6769 | Train Acc 0.887 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 620/657 | Loss 0.6766 | Train Acc 0.887 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 630/657 | Loss 0.6760 | Train Acc 0.887 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 640/657 | Loss 0.6752 | Train Acc 0.888 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 650/657 | Loss 0.6745 | Train Acc 0.888 | 88 img/s | VRAM 115/493 MB
#     Epoch 2/20 | Batch 657/657 | Loss 0.6744 | Train Acc 0.888 | 23 img/s | VRAM 86/493 MB
#   ▶ Phase VAL ...
#
#   ✅ Epoch  2 résumé | Loss 0.6744 | Train Acc 0.8876 | Val Acc 0.8997 | Train 477.7s | Val 19.4s  | VRAM peak 346 MB  ⭐ NOUVEAU MEILLEUR MODÈLE SAUVEGARDÉ
#
# 📌 Epoch 3/20  —  LR backbone=9.76e-05 | LR classifier=2.93e-04
#   ▶ Phase TRAIN ...
#     Epoch 3/20 | Batch  10/657 | Loss 0.6405 | Train Acc 0.914 | 100 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch  20/657 | Loss 0.6456 | Train Acc 0.910 | 87 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch  30/657 | Loss 0.6406 | Train Acc 0.912 | 92 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch  40/657 | Loss 0.6487 | Train Acc 0.907 | 87 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch  50/657 | Loss 0.6470 | Train Acc 0.905 | 90 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch  60/657 | Loss 0.6466 | Train Acc 0.903 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch  70/657 | Loss 0.6460 | Train Acc 0.905 | 90 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch  80/657 | Loss 0.6436 | Train Acc 0.907 | 90 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch  90/657 | Loss 0.6421 | Train Acc 0.909 | 90 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 100/657 | Loss 0.6392 | Train Acc 0.911 | 91 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 110/657 | Loss 0.6387 | Train Acc 0.911 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 120/657 | Loss 0.6357 | Train Acc 0.911 | 90 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 130/657 | Loss 0.6343 | Train Acc 0.912 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 140/657 | Loss 0.6331 | Train Acc 0.912 | 90 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 150/657 | Loss 0.6328 | Train Acc 0.912 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 160/657 | Loss 0.6319 | Train Acc 0.912 | 90 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 170/657 | Loss 0.6334 | Train Acc 0.912 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 180/657 | Loss 0.6330 | Train Acc 0.912 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 190/657 | Loss 0.6321 | Train Acc 0.912 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 200/657 | Loss 0.6329 | Train Acc 0.911 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 210/657 | Loss 0.6334 | Train Acc 0.911 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 220/657 | Loss 0.6329 | Train Acc 0.911 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 230/657 | Loss 0.6319 | Train Acc 0.911 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 240/657 | Loss 0.6311 | Train Acc 0.911 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 250/657 | Loss 0.6311 | Train Acc 0.911 | 90 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 260/657 | Loss 0.6304 | Train Acc 0.911 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 270/657 | Loss 0.6294 | Train Acc 0.911 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 280/657 | Loss 0.6286 | Train Acc 0.911 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 290/657 | Loss 0.6289 | Train Acc 0.911 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 300/657 | Loss 0.6279 | Train Acc 0.911 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 310/657 | Loss 0.6273 | Train Acc 0.911 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 320/657 | Loss 0.6273 | Train Acc 0.912 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 330/657 | Loss 0.6263 | Train Acc 0.913 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 340/657 | Loss 0.6265 | Train Acc 0.913 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 350/657 | Loss 0.6260 | Train Acc 0.913 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 360/657 | Loss 0.6271 | Train Acc 0.912 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 370/657 | Loss 0.6268 | Train Acc 0.913 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 380/657 | Loss 0.6270 | Train Acc 0.913 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 390/657 | Loss 0.6267 | Train Acc 0.913 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 400/657 | Loss 0.6270 | Train Acc 0.912 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 410/657 | Loss 0.6266 | Train Acc 0.912 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 420/657 | Loss 0.6262 | Train Acc 0.913 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 430/657 | Loss 0.6263 | Train Acc 0.913 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 440/657 | Loss 0.6259 | Train Acc 0.913 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 450/657 | Loss 0.6258 | Train Acc 0.913 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 460/657 | Loss 0.6260 | Train Acc 0.913 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 470/657 | Loss 0.6261 | Train Acc 0.913 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 480/657 | Loss 0.6262 | Train Acc 0.913 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 490/657 | Loss 0.6260 | Train Acc 0.913 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 500/657 | Loss 0.6255 | Train Acc 0.913 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 510/657 | Loss 0.6248 | Train Acc 0.913 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 520/657 | Loss 0.6247 | Train Acc 0.913 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 530/657 | Loss 0.6244 | Train Acc 0.914 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 540/657 | Loss 0.6243 | Train Acc 0.914 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 550/657 | Loss 0.6245 | Train Acc 0.914 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 560/657 | Loss 0.6241 | Train Acc 0.914 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 570/657 | Loss 0.6241 | Train Acc 0.914 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 580/657 | Loss 0.6240 | Train Acc 0.914 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 590/657 | Loss 0.6238 | Train Acc 0.914 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 600/657 | Loss 0.6234 | Train Acc 0.914 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 610/657 | Loss 0.6228 | Train Acc 0.915 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 620/657 | Loss 0.6225 | Train Acc 0.915 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 630/657 | Loss 0.6217 | Train Acc 0.915 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 640/657 | Loss 0.6215 | Train Acc 0.916 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 650/657 | Loss 0.6211 | Train Acc 0.916 | 89 img/s | VRAM 115/596 MB
#     Epoch 3/20 | Batch 657/657 | Loss 0.6210 | Train Acc 0.916 | 24 img/s | VRAM 86/596 MB
#   ▶ Phase VAL ...
#
#   ✅ Epoch  3 résumé | Loss 0.6210 | Train Acc 0.9156 | Val Acc 0.9058 | Train 470.1s | Val 18.0s  | VRAM peak 346 MB  ⭐ NOUVEAU MEILLEUR MODÈLE SAUVEGARDÉ
#
# 📌 Epoch 4/20  —  LR backbone=9.46e-05 | LR classifier=2.84e-04
#   ▶ Phase TRAIN ...
#     Epoch 4/20 | Batch  10/657 | Loss 0.6134 | Train Acc 0.914 | 77 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch  20/657 | Loss 0.6097 | Train Acc 0.916 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch  30/657 | Loss 0.6020 | Train Acc 0.921 | 84 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch  40/657 | Loss 0.6001 | Train Acc 0.923 | 88 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch  50/657 | Loss 0.6019 | Train Acc 0.923 | 85 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch  60/657 | Loss 0.5988 | Train Acc 0.924 | 88 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch  70/657 | Loss 0.5983 | Train Acc 0.923 | 86 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch  80/657 | Loss 0.5987 | Train Acc 0.923 | 88 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch  90/657 | Loss 0.5993 | Train Acc 0.923 | 87 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 100/657 | Loss 0.5973 | Train Acc 0.923 | 88 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 110/657 | Loss 0.5981 | Train Acc 0.923 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 120/657 | Loss 0.5995 | Train Acc 0.922 | 88 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 130/657 | Loss 0.5993 | Train Acc 0.923 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 140/657 | Loss 0.5972 | Train Acc 0.924 | 88 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 150/657 | Loss 0.5972 | Train Acc 0.924 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 160/657 | Loss 0.5967 | Train Acc 0.925 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 170/657 | Loss 0.5968 | Train Acc 0.924 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 180/657 | Loss 0.5968 | Train Acc 0.924 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 190/657 | Loss 0.5957 | Train Acc 0.925 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 200/657 | Loss 0.5955 | Train Acc 0.925 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 210/657 | Loss 0.5964 | Train Acc 0.924 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 220/657 | Loss 0.5969 | Train Acc 0.924 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 230/657 | Loss 0.5971 | Train Acc 0.924 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 240/657 | Loss 0.5969 | Train Acc 0.924 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 250/657 | Loss 0.5962 | Train Acc 0.924 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 260/657 | Loss 0.5956 | Train Acc 0.925 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 270/657 | Loss 0.5966 | Train Acc 0.924 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 280/657 | Loss 0.5966 | Train Acc 0.924 | 90 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 290/657 | Loss 0.5966 | Train Acc 0.924 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 300/657 | Loss 0.5965 | Train Acc 0.924 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 310/657 | Loss 0.5958 | Train Acc 0.925 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 320/657 | Loss 0.5961 | Train Acc 0.925 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 330/657 | Loss 0.5961 | Train Acc 0.924 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 340/657 | Loss 0.5957 | Train Acc 0.925 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 350/657 | Loss 0.5952 | Train Acc 0.925 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 360/657 | Loss 0.5951 | Train Acc 0.925 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 370/657 | Loss 0.5946 | Train Acc 0.926 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 380/657 | Loss 0.5943 | Train Acc 0.926 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 390/657 | Loss 0.5945 | Train Acc 0.926 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 400/657 | Loss 0.5945 | Train Acc 0.926 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 410/657 | Loss 0.5938 | Train Acc 0.926 | 90 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 420/657 | Loss 0.5933 | Train Acc 0.926 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 430/657 | Loss 0.5929 | Train Acc 0.926 | 90 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 440/657 | Loss 0.5925 | Train Acc 0.927 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 450/657 | Loss 0.5923 | Train Acc 0.927 | 90 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 460/657 | Loss 0.5920 | Train Acc 0.927 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 470/657 | Loss 0.5917 | Train Acc 0.927 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 480/657 | Loss 0.5916 | Train Acc 0.927 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 490/657 | Loss 0.5916 | Train Acc 0.927 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 500/657 | Loss 0.5917 | Train Acc 0.927 | 90 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 510/657 | Loss 0.5917 | Train Acc 0.927 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 520/657 | Loss 0.5911 | Train Acc 0.927 | 90 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 530/657 | Loss 0.5911 | Train Acc 0.927 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 540/657 | Loss 0.5911 | Train Acc 0.927 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 550/657 | Loss 0.5916 | Train Acc 0.927 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 560/657 | Loss 0.5910 | Train Acc 0.928 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 570/657 | Loss 0.5904 | Train Acc 0.928 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 580/657 | Loss 0.5901 | Train Acc 0.928 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 590/657 | Loss 0.5900 | Train Acc 0.928 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 600/657 | Loss 0.5904 | Train Acc 0.928 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 610/657 | Loss 0.5903 | Train Acc 0.928 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 620/657 | Loss 0.5902 | Train Acc 0.928 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 630/657 | Loss 0.5900 | Train Acc 0.928 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 640/657 | Loss 0.5896 | Train Acc 0.928 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 650/657 | Loss 0.5894 | Train Acc 0.928 | 89 img/s | VRAM 115/596 MB
#     Epoch 4/20 | Batch 657/657 | Loss 0.5894 | Train Acc 0.928 | 24 img/s | VRAM 86/596 MB
#   ▶ Phase VAL ...
#
#   ✅ Epoch  4 résumé | Loss 0.5894 | Train Acc 0.9283 | Val Acc 0.9267 | Train 470.7s | Val 18.1s  | VRAM peak 346 MB  ⭐ NOUVEAU MEILLEUR MODÈLE SAUVEGARDÉ
#
# 📌 Epoch 5/20  —  LR backbone=9.05e-05 | LR classifier=2.71e-04
#   ▶ Phase TRAIN ...
#     Epoch 5/20 | Batch  10/657 | Loss 0.5843 | Train Acc 0.938 | 101 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch  20/657 | Loss 0.5685 | Train Acc 0.940 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch  30/657 | Loss 0.5770 | Train Acc 0.933 | 93 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch  40/657 | Loss 0.5790 | Train Acc 0.931 | 88 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch  50/657 | Loss 0.5730 | Train Acc 0.935 | 90 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch  60/657 | Loss 0.5742 | Train Acc 0.934 | 87 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch  70/657 | Loss 0.5762 | Train Acc 0.932 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch  80/657 | Loss 0.5744 | Train Acc 0.932 | 88 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch  90/657 | Loss 0.5738 | Train Acc 0.934 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 100/657 | Loss 0.5730 | Train Acc 0.934 | 88 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 110/657 | Loss 0.5729 | Train Acc 0.936 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 120/657 | Loss 0.5742 | Train Acc 0.935 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 130/657 | Loss 0.5729 | Train Acc 0.936 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 140/657 | Loss 0.5732 | Train Acc 0.936 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 150/657 | Loss 0.5735 | Train Acc 0.936 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 160/657 | Loss 0.5734 | Train Acc 0.937 | 90 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 170/657 | Loss 0.5733 | Train Acc 0.937 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 180/657 | Loss 0.5734 | Train Acc 0.937 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 190/657 | Loss 0.5742 | Train Acc 0.936 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 200/657 | Loss 0.5735 | Train Acc 0.937 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 210/657 | Loss 0.5740 | Train Acc 0.937 | 88 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 220/657 | Loss 0.5732 | Train Acc 0.937 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 230/657 | Loss 0.5740 | Train Acc 0.937 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 240/657 | Loss 0.5736 | Train Acc 0.937 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 250/657 | Loss 0.5731 | Train Acc 0.938 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 260/657 | Loss 0.5732 | Train Acc 0.937 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 270/657 | Loss 0.5728 | Train Acc 0.937 | 90 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 280/657 | Loss 0.5728 | Train Acc 0.937 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 290/657 | Loss 0.5723 | Train Acc 0.938 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 300/657 | Loss 0.5718 | Train Acc 0.938 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 310/657 | Loss 0.5709 | Train Acc 0.938 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 320/657 | Loss 0.5709 | Train Acc 0.939 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 330/657 | Loss 0.5707 | Train Acc 0.939 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 340/657 | Loss 0.5700 | Train Acc 0.939 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 350/657 | Loss 0.5695 | Train Acc 0.939 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 360/657 | Loss 0.5693 | Train Acc 0.939 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 370/657 | Loss 0.5685 | Train Acc 0.940 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 380/657 | Loss 0.5685 | Train Acc 0.940 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 390/657 | Loss 0.5687 | Train Acc 0.940 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 400/657 | Loss 0.5685 | Train Acc 0.940 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 410/657 | Loss 0.5689 | Train Acc 0.939 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 420/657 | Loss 0.5695 | Train Acc 0.939 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 430/657 | Loss 0.5697 | Train Acc 0.939 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 440/657 | Loss 0.5698 | Train Acc 0.939 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 450/657 | Loss 0.5690 | Train Acc 0.940 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 460/657 | Loss 0.5688 | Train Acc 0.940 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 470/657 | Loss 0.5685 | Train Acc 0.940 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 480/657 | Loss 0.5682 | Train Acc 0.940 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 490/657 | Loss 0.5685 | Train Acc 0.940 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 500/657 | Loss 0.5684 | Train Acc 0.940 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 510/657 | Loss 0.5680 | Train Acc 0.940 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 520/657 | Loss 0.5676 | Train Acc 0.940 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 530/657 | Loss 0.5674 | Train Acc 0.940 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 540/657 | Loss 0.5671 | Train Acc 0.940 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 550/657 | Loss 0.5672 | Train Acc 0.940 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 560/657 | Loss 0.5671 | Train Acc 0.941 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 570/657 | Loss 0.5667 | Train Acc 0.941 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 580/657 | Loss 0.5670 | Train Acc 0.941 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 590/657 | Loss 0.5671 | Train Acc 0.941 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 600/657 | Loss 0.5668 | Train Acc 0.941 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 610/657 | Loss 0.5665 | Train Acc 0.941 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 620/657 | Loss 0.5664 | Train Acc 0.941 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 630/657 | Loss 0.5662 | Train Acc 0.941 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 640/657 | Loss 0.5662 | Train Acc 0.941 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 650/657 | Loss 0.5658 | Train Acc 0.941 | 89 img/s | VRAM 115/596 MB
#     Epoch 5/20 | Batch 657/657 | Loss 0.5656 | Train Acc 0.942 | 24 img/s | VRAM 86/596 MB
#   ▶ Phase VAL ...
#
#   ✅ Epoch  5 résumé | Loss 0.5656 | Train Acc 0.9415 | Val Acc 0.9350 | Train 470.1s | Val 18.5s  | VRAM peak 346 MB  ⭐ NOUVEAU MEILLEUR MODÈLE SAUVEGARDÉ
#
# 📌 Epoch 6/20  —  LR backbone=8.55e-05 | LR classifier=2.56e-04
#   ▶ Phase TRAIN ...
#     Epoch 6/20 | Batch  10/657 | Loss 0.5662 | Train Acc 0.938 | 81 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch  20/657 | Loss 0.5647 | Train Acc 0.945 | 90 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch  30/657 | Loss 0.5612 | Train Acc 0.943 | 85 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch  40/657 | Loss 0.5593 | Train Acc 0.943 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch  50/657 | Loss 0.5566 | Train Acc 0.945 | 86 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch  60/657 | Loss 0.5570 | Train Acc 0.944 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch  70/657 | Loss 0.5571 | Train Acc 0.946 | 87 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch  80/657 | Loss 0.5593 | Train Acc 0.944 | 88 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch  90/657 | Loss 0.5614 | Train Acc 0.943 | 87 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 100/657 | Loss 0.5593 | Train Acc 0.944 | 88 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 110/657 | Loss 0.5579 | Train Acc 0.944 | 87 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 120/657 | Loss 0.5570 | Train Acc 0.944 | 88 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 130/657 | Loss 0.5557 | Train Acc 0.944 | 87 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 140/657 | Loss 0.5554 | Train Acc 0.945 | 88 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 150/657 | Loss 0.5560 | Train Acc 0.945 | 88 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 160/657 | Loss 0.5555 | Train Acc 0.946 | 88 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 170/657 | Loss 0.5551 | Train Acc 0.946 | 88 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 180/657 | Loss 0.5547 | Train Acc 0.946 | 88 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 190/657 | Loss 0.5541 | Train Acc 0.947 | 88 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 200/657 | Loss 0.5537 | Train Acc 0.947 | 88 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 210/657 | Loss 0.5536 | Train Acc 0.946 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 220/657 | Loss 0.5543 | Train Acc 0.946 | 88 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 230/657 | Loss 0.5543 | Train Acc 0.946 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 240/657 | Loss 0.5542 | Train Acc 0.946 | 88 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 250/657 | Loss 0.5545 | Train Acc 0.946 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 260/657 | Loss 0.5545 | Train Acc 0.946 | 88 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 270/657 | Loss 0.5544 | Train Acc 0.946 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 280/657 | Loss 0.5545 | Train Acc 0.946 | 88 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 290/657 | Loss 0.5540 | Train Acc 0.946 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 300/657 | Loss 0.5542 | Train Acc 0.947 | 88 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 310/657 | Loss 0.5551 | Train Acc 0.946 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 320/657 | Loss 0.5546 | Train Acc 0.946 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 330/657 | Loss 0.5550 | Train Acc 0.946 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 340/657 | Loss 0.5544 | Train Acc 0.946 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 350/657 | Loss 0.5548 | Train Acc 0.946 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 360/657 | Loss 0.5540 | Train Acc 0.947 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 370/657 | Loss 0.5535 | Train Acc 0.947 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 380/657 | Loss 0.5532 | Train Acc 0.947 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 390/657 | Loss 0.5527 | Train Acc 0.948 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 400/657 | Loss 0.5524 | Train Acc 0.948 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 410/657 | Loss 0.5520 | Train Acc 0.948 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 420/657 | Loss 0.5518 | Train Acc 0.948 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 430/657 | Loss 0.5518 | Train Acc 0.948 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 440/657 | Loss 0.5517 | Train Acc 0.948 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 450/657 | Loss 0.5516 | Train Acc 0.948 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 460/657 | Loss 0.5513 | Train Acc 0.949 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 470/657 | Loss 0.5515 | Train Acc 0.948 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 480/657 | Loss 0.5514 | Train Acc 0.948 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 490/657 | Loss 0.5514 | Train Acc 0.948 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 500/657 | Loss 0.5509 | Train Acc 0.948 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 510/657 | Loss 0.5509 | Train Acc 0.948 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 520/657 | Loss 0.5507 | Train Acc 0.948 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 530/657 | Loss 0.5506 | Train Acc 0.949 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 540/657 | Loss 0.5503 | Train Acc 0.949 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 550/657 | Loss 0.5502 | Train Acc 0.949 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 560/657 | Loss 0.5500 | Train Acc 0.949 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 570/657 | Loss 0.5501 | Train Acc 0.949 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 580/657 | Loss 0.5500 | Train Acc 0.949 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 590/657 | Loss 0.5495 | Train Acc 0.950 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 600/657 | Loss 0.5493 | Train Acc 0.950 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 610/657 | Loss 0.5493 | Train Acc 0.950 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 620/657 | Loss 0.5492 | Train Acc 0.950 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 630/657 | Loss 0.5488 | Train Acc 0.950 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 640/657 | Loss 0.5484 | Train Acc 0.950 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 650/657 | Loss 0.5481 | Train Acc 0.950 | 89 img/s | VRAM 115/596 MB
#     Epoch 6/20 | Batch 657/657 | Loss 0.5479 | Train Acc 0.951 | 24 img/s | VRAM 86/596 MB
#   ▶ Phase VAL ...
#
#   ✅ Epoch  6 résumé | Loss 0.5479 | Train Acc 0.9506 | Val Acc 0.9374 | Train 471.3s | Val 18.2s  | VRAM peak 346 MB  ⭐ NOUVEAU MEILLEUR MODÈLE SAUVEGARDÉ
#
# 📌 Epoch 7/20  —  LR backbone=7.96e-05 | LR classifier=2.38e-04
#   ▶ Phase TRAIN ...
#     Epoch 7/20 | Batch  10/657 | Loss 0.5460 | Train Acc 0.953 | 74 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch  20/657 | Loss 0.5389 | Train Acc 0.952 | 87 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch  30/657 | Loss 0.5362 | Train Acc 0.953 | 87 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch  40/657 | Loss 0.5329 | Train Acc 0.955 | 88 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch  50/657 | Loss 0.5349 | Train Acc 0.955 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch  60/657 | Loss 0.5332 | Train Acc 0.957 | 88 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch  70/657 | Loss 0.5342 | Train Acc 0.956 | 90 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch  80/657 | Loss 0.5361 | Train Acc 0.956 | 88 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch  90/657 | Loss 0.5346 | Train Acc 0.957 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 100/657 | Loss 0.5342 | Train Acc 0.957 | 88 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 110/657 | Loss 0.5340 | Train Acc 0.957 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 120/657 | Loss 0.5333 | Train Acc 0.957 | 88 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 130/657 | Loss 0.5331 | Train Acc 0.956 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 140/657 | Loss 0.5315 | Train Acc 0.957 | 88 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 150/657 | Loss 0.5305 | Train Acc 0.958 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 160/657 | Loss 0.5313 | Train Acc 0.957 | 88 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 170/657 | Loss 0.5319 | Train Acc 0.957 | 88 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 180/657 | Loss 0.5314 | Train Acc 0.957 | 88 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 190/657 | Loss 0.5317 | Train Acc 0.957 | 88 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 200/657 | Loss 0.5326 | Train Acc 0.957 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 210/657 | Loss 0.5325 | Train Acc 0.957 | 88 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 220/657 | Loss 0.5332 | Train Acc 0.957 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 230/657 | Loss 0.5328 | Train Acc 0.957 | 88 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 240/657 | Loss 0.5322 | Train Acc 0.957 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 250/657 | Loss 0.5327 | Train Acc 0.957 | 88 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 260/657 | Loss 0.5331 | Train Acc 0.957 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 270/657 | Loss 0.5334 | Train Acc 0.956 | 88 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 280/657 | Loss 0.5339 | Train Acc 0.956 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 290/657 | Loss 0.5336 | Train Acc 0.956 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 300/657 | Loss 0.5335 | Train Acc 0.957 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 310/657 | Loss 0.5343 | Train Acc 0.956 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 320/657 | Loss 0.5341 | Train Acc 0.956 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 330/657 | Loss 0.5346 | Train Acc 0.956 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 340/657 | Loss 0.5346 | Train Acc 0.956 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 350/657 | Loss 0.5350 | Train Acc 0.956 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 360/657 | Loss 0.5351 | Train Acc 0.956 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 370/657 | Loss 0.5353 | Train Acc 0.956 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 380/657 | Loss 0.5357 | Train Acc 0.956 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 390/657 | Loss 0.5355 | Train Acc 0.956 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 400/657 | Loss 0.5348 | Train Acc 0.957 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 410/657 | Loss 0.5350 | Train Acc 0.957 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 420/657 | Loss 0.5353 | Train Acc 0.956 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 430/657 | Loss 0.5349 | Train Acc 0.957 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 440/657 | Loss 0.5347 | Train Acc 0.957 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 450/657 | Loss 0.5343 | Train Acc 0.957 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 460/657 | Loss 0.5343 | Train Acc 0.957 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 470/657 | Loss 0.5341 | Train Acc 0.957 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 480/657 | Loss 0.5340 | Train Acc 0.957 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 490/657 | Loss 0.5340 | Train Acc 0.957 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 500/657 | Loss 0.5340 | Train Acc 0.957 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 510/657 | Loss 0.5339 | Train Acc 0.957 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 520/657 | Loss 0.5335 | Train Acc 0.958 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 530/657 | Loss 0.5333 | Train Acc 0.958 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 540/657 | Loss 0.5332 | Train Acc 0.958 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 550/657 | Loss 0.5332 | Train Acc 0.958 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 560/657 | Loss 0.5330 | Train Acc 0.958 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 570/657 | Loss 0.5332 | Train Acc 0.958 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 580/657 | Loss 0.5330 | Train Acc 0.958 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 590/657 | Loss 0.5329 | Train Acc 0.958 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 600/657 | Loss 0.5330 | Train Acc 0.958 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 610/657 | Loss 0.5330 | Train Acc 0.958 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 620/657 | Loss 0.5331 | Train Acc 0.958 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 630/657 | Loss 0.5330 | Train Acc 0.958 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 640/657 | Loss 0.5333 | Train Acc 0.958 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 650/657 | Loss 0.5333 | Train Acc 0.958 | 89 img/s | VRAM 115/596 MB
#     Epoch 7/20 | Batch 657/657 | Loss 0.5332 | Train Acc 0.958 | 24 img/s | VRAM 86/596 MB
#   ▶ Phase VAL ...
#
#   ✅ Epoch  7 résumé | Loss 0.5332 | Train Acc 0.9576 | Val Acc 0.9352 | Train 471.4s | Val 18.4s  | VRAM peak 346 MB
#
# 📌 Epoch 8/20  —  LR backbone=7.30e-05 | LR classifier=2.18e-04
#   ▶ Phase TRAIN ...
#     Epoch 8/20 | Batch  10/657 | Loss 0.5390 | Train Acc 0.955 | 103 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch  20/657 | Loss 0.5331 | Train Acc 0.958 | 88 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch  30/657 | Loss 0.5259 | Train Acc 0.958 | 93 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch  40/657 | Loss 0.5250 | Train Acc 0.959 | 88 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch  50/657 | Loss 0.5271 | Train Acc 0.958 | 91 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch  60/657 | Loss 0.5255 | Train Acc 0.960 | 88 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch  70/657 | Loss 0.5267 | Train Acc 0.960 | 90 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch  80/657 | Loss 0.5254 | Train Acc 0.961 | 90 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch  90/657 | Loss 0.5241 | Train Acc 0.961 | 90 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 100/657 | Loss 0.5233 | Train Acc 0.962 | 90 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 110/657 | Loss 0.5225 | Train Acc 0.963 | 89 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 120/657 | Loss 0.5241 | Train Acc 0.961 | 90 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 130/657 | Loss 0.5247 | Train Acc 0.960 | 89 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 140/657 | Loss 0.5237 | Train Acc 0.961 | 90 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 150/657 | Loss 0.5238 | Train Acc 0.960 | 89 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 160/657 | Loss 0.5244 | Train Acc 0.960 | 90 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 170/657 | Loss 0.5237 | Train Acc 0.961 | 89 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 180/657 | Loss 0.5233 | Train Acc 0.961 | 90 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 190/657 | Loss 0.5229 | Train Acc 0.962 | 89 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 200/657 | Loss 0.5222 | Train Acc 0.962 | 90 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 210/657 | Loss 0.5223 | Train Acc 0.962 | 90 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 220/657 | Loss 0.5220 | Train Acc 0.962 | 90 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 230/657 | Loss 0.5222 | Train Acc 0.962 | 90 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 240/657 | Loss 0.5216 | Train Acc 0.963 | 90 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 250/657 | Loss 0.5212 | Train Acc 0.963 | 90 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 260/657 | Loss 0.5210 | Train Acc 0.963 | 90 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 270/657 | Loss 0.5215 | Train Acc 0.963 | 90 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 280/657 | Loss 0.5215 | Train Acc 0.962 | 90 img/s | VRAM 115/596 MB
#     Epoch 8/20 | Batch 290/657 | Loss 0.5210 | Train Acc 0.963 | 90 img/s | VRAM 115/596 MB
# ...
#     Epoch 18/20 | Batch 370/657 | Loss 0.4787 | Train Acc 0.981 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 380/657 | Loss 0.4790 | Train Acc 0.981 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 390/657 | Loss 0.4790 | Train Acc 0.981 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 400/657 | Loss 0.4791 | Train Acc 0.981 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 410/657 | Loss 0.4791 | Train Acc 0.981 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 420/657 | Loss 0.4791 | Train Acc 0.981 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 430/657 | Loss 0.4788 | Train Acc 0.981 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 440/657 | Loss 0.4787 | Train Acc 0.981 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 450/657 | Loss 0.4783 | Train Acc 0.982 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 460/657 | Loss 0.4780 | Train Acc 0.982 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 470/657 | Loss 0.4782 | Train Acc 0.982 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 480/657 | Loss 0.4781 | Train Acc 0.982 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 490/657 | Loss 0.4781 | Train Acc 0.982 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 500/657 | Loss 0.4782 | Train Acc 0.982 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 510/657 | Loss 0.4783 | Train Acc 0.981 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 520/657 | Loss 0.4783 | Train Acc 0.981 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 530/657 | Loss 0.4781 | Train Acc 0.981 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 540/657 | Loss 0.4781 | Train Acc 0.981 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 550/657 | Loss 0.4781 | Train Acc 0.981 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 560/657 | Loss 0.4781 | Train Acc 0.981 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 570/657 | Loss 0.4781 | Train Acc 0.981 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 580/657 | Loss 0.4779 | Train Acc 0.981 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 590/657 | Loss 0.4778 | Train Acc 0.982 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 600/657 | Loss 0.4777 | Train Acc 0.982 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 610/657 | Loss 0.4777 | Train Acc 0.982 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 620/657 | Loss 0.4778 | Train Acc 0.982 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 630/657 | Loss 0.4777 | Train Acc 0.982 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 640/657 | Loss 0.4777 | Train Acc 0.982 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 650/657 | Loss 0.4776 | Train Acc 0.982 | 90 img/s | VRAM 115/596 MB
#     Epoch 18/20 | Batch 657/657 | Loss 0.4776 | Train Acc 0.982 | 24 img/s | VRAM 86/596 MB
#   ▶ Phase VAL ...
#
#   ✅ Epoch 18 résumé | Loss 0.4776 | Train Acc 0.9819 | Val Acc 0.9734 | Train 465.8s | Val 18.0s  | VRAM peak 346 MB  ⭐ NOUVEAU MEILLEUR MODÈLE SAUVEGARDÉ
#
# 📌 Epoch 19/20  —  LR backbone=3.42e-06 | LR classifier=8.32e-06
#   ▶ Phase TRAIN ...
#     Epoch 19/20 | Batch  10/657 | Loss 0.4798 | Train Acc 0.978 | 75 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch  20/657 | Loss 0.4782 | Train Acc 0.984 | 87 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch  30/657 | Loss 0.4772 | Train Acc 0.982 | 83 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch  40/657 | Loss 0.4762 | Train Acc 0.982 | 87 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch  50/657 | Loss 0.4746 | Train Acc 0.983 | 84 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch  60/657 | Loss 0.4742 | Train Acc 0.984 | 87 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch  70/657 | Loss 0.4746 | Train Acc 0.985 | 85 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch  80/657 | Loss 0.4773 | Train Acc 0.983 | 87 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch  90/657 | Loss 0.4758 | Train Acc 0.984 | 87 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 100/657 | Loss 0.4753 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 110/657 | Loss 0.4750 | Train Acc 0.985 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 120/657 | Loss 0.4755 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 130/657 | Loss 0.4762 | Train Acc 0.983 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 140/657 | Loss 0.4752 | Train Acc 0.984 | 87 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 150/657 | Loss 0.4762 | Train Acc 0.983 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 160/657 | Loss 0.4762 | Train Acc 0.983 | 87 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 170/657 | Loss 0.4754 | Train Acc 0.983 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 180/657 | Loss 0.4751 | Train Acc 0.983 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 190/657 | Loss 0.4751 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 200/657 | Loss 0.4745 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 210/657 | Loss 0.4745 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 220/657 | Loss 0.4750 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 230/657 | Loss 0.4752 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 240/657 | Loss 0.4749 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 250/657 | Loss 0.4743 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 260/657 | Loss 0.4746 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 270/657 | Loss 0.4744 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 280/657 | Loss 0.4738 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 290/657 | Loss 0.4737 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 300/657 | Loss 0.4735 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 310/657 | Loss 0.4737 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 320/657 | Loss 0.4739 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 330/657 | Loss 0.4739 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 340/657 | Loss 0.4740 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 350/657 | Loss 0.4741 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 360/657 | Loss 0.4741 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 370/657 | Loss 0.4742 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 380/657 | Loss 0.4740 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 390/657 | Loss 0.4740 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 400/657 | Loss 0.4740 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 410/657 | Loss 0.4739 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 420/657 | Loss 0.4739 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 430/657 | Loss 0.4737 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 440/657 | Loss 0.4738 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 450/657 | Loss 0.4738 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 460/657 | Loss 0.4740 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 470/657 | Loss 0.4738 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 480/657 | Loss 0.4739 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 490/657 | Loss 0.4738 | Train Acc 0.985 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 500/657 | Loss 0.4737 | Train Acc 0.985 | 88 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 510/657 | Loss 0.4738 | Train Acc 0.985 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 520/657 | Loss 0.4741 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 530/657 | Loss 0.4742 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 540/657 | Loss 0.4742 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 550/657 | Loss 0.4741 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 560/657 | Loss 0.4740 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 570/657 | Loss 0.4741 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 580/657 | Loss 0.4741 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 590/657 | Loss 0.4741 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 600/657 | Loss 0.4742 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 610/657 | Loss 0.4744 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 620/657 | Loss 0.4744 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 630/657 | Loss 0.4745 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 640/657 | Loss 0.4744 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 650/657 | Loss 0.4743 | Train Acc 0.984 | 89 img/s | VRAM 115/596 MB
#     Epoch 19/20 | Batch 657/657 | Loss 0.4743 | Train Acc 0.984 | 24 img/s | VRAM 86/596 MB
#   ▶ Phase VAL ...
#
#   ✅ Epoch 19 résumé | Loss 0.4743 | Train Acc 0.9843 | Val Acc 0.9706 | Train 473.1s | Val 18.2s  | VRAM peak 346 MB
#
# 📌 Epoch 20/20  —  LR backbone=1.61e-06 | LR classifier=2.84e-06
#   ▶ Phase TRAIN ...
#     Epoch 20/20 | Batch  10/657 | Loss 0.4837 | Train Acc 0.977 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch  20/657 | Loss 0.4803 | Train Acc 0.980 | 87 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch  30/657 | Loss 0.4768 | Train Acc 0.981 | 91 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch  40/657 | Loss 0.4744 | Train Acc 0.982 | 88 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch  50/657 | Loss 0.4740 | Train Acc 0.983 | 91 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch  60/657 | Loss 0.4738 | Train Acc 0.983 | 88 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch  70/657 | Loss 0.4731 | Train Acc 0.983 | 90 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch  80/657 | Loss 0.4725 | Train Acc 0.983 | 88 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch  90/657 | Loss 0.4736 | Train Acc 0.983 | 90 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 100/657 | Loss 0.4732 | Train Acc 0.984 | 88 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 110/657 | Loss 0.4739 | Train Acc 0.983 | 90 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 120/657 | Loss 0.4744 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 130/657 | Loss 0.4752 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 140/657 | Loss 0.4753 | Train Acc 0.982 | 90 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 150/657 | Loss 0.4750 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 160/657 | Loss 0.4745 | Train Acc 0.983 | 90 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 170/657 | Loss 0.4754 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 180/657 | Loss 0.4755 | Train Acc 0.983 | 90 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 190/657 | Loss 0.4759 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 200/657 | Loss 0.4757 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 210/657 | Loss 0.4759 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 220/657 | Loss 0.4758 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 230/657 | Loss 0.4759 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 240/657 | Loss 0.4752 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 250/657 | Loss 0.4750 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 260/657 | Loss 0.4750 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 270/657 | Loss 0.4749 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 280/657 | Loss 0.4752 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 290/657 | Loss 0.4752 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 300/657 | Loss 0.4755 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 310/657 | Loss 0.4761 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 320/657 | Loss 0.4762 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 330/657 | Loss 0.4762 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 340/657 | Loss 0.4762 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 350/657 | Loss 0.4765 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 360/657 | Loss 0.4769 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 370/657 | Loss 0.4769 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 380/657 | Loss 0.4771 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 390/657 | Loss 0.4770 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 400/657 | Loss 0.4765 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 410/657 | Loss 0.4762 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 420/657 | Loss 0.4762 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 430/657 | Loss 0.4760 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 440/657 | Loss 0.4760 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 450/657 | Loss 0.4760 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 460/657 | Loss 0.4761 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 470/657 | Loss 0.4760 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 480/657 | Loss 0.4759 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 490/657 | Loss 0.4760 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 500/657 | Loss 0.4759 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 510/657 | Loss 0.4756 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 520/657 | Loss 0.4757 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 530/657 | Loss 0.4757 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 540/657 | Loss 0.4757 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 550/657 | Loss 0.4757 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 560/657 | Loss 0.4758 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 570/657 | Loss 0.4758 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 580/657 | Loss 0.4760 | Train Acc 0.983 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 590/657 | Loss 0.4762 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 600/657 | Loss 0.4762 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 610/657 | Loss 0.4763 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 620/657 | Loss 0.4764 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 630/657 | Loss 0.4765 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 640/657 | Loss 0.4763 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 650/657 | Loss 0.4761 | Train Acc 0.982 | 89 img/s | VRAM 115/596 MB
#     Epoch 20/20 | Batch 657/657 | Loss 0.4761 | Train Acc 0.982 | 24 img/s | VRAM 86/596 MB
#   ▶ Phase VAL ...
#
#   ✅ Epoch 20 résumé | Loss 0.4761 | Train Acc 0.9824 | Val Acc 0.9708 | Train 468.8s | Val 18.2s  | VRAM peak 346 MB
#
# ============================================================
#   🏁 Entraînement terminé en 9823.6s
#   🏆 Meilleure Val Acc : 0.9734
#   💾 Meilleur modèle  : /content/best_model_finetuned.pth
# ============================================================

# %%
# ── Cellule 8 : Résumé final + copie vers Drive ───────────────────────────────
import shutil

print('=' * 60)
print('📊  RÉSUMÉ FINAL')
print('=' * 60)
print(f'  {"Epoch":>5}  {"Loss":>8}  {"Train Acc":>10}  {"Val Acc":>10}')
print('  ' + '-' * 40)
for h in history:
    best_mark = ' ⭐' if h['val_acc'] == best_acc else ''
    print(f'  {h["epoch"]:>5}  {h["loss"]:>8.4f}  {h["train_acc"]:>10.4f}  {h["val_acc"]:>10.4f}{best_mark}')

# Sauvegarde aussi vers Drive
drive_save = '/content/drive/MyDrive/best_model_finetuned.pth'
shutil.copy('/content/best_model_finetuned.pth', drive_save)
print(f'\n  ✅ Modèle copié vers Google Drive : {drive_save}')
print('=' * 60)
# Out:
# ============================================================
# 📊  RÉSUMÉ FINAL
# ============================================================
#   Epoch      Loss   Train Acc     Val Acc
#   ----------------------------------------
#       1    0.8462      0.7980      0.8578
#       2    0.6744      0.8876      0.8997
#       3    0.6210      0.9156      0.9058
#       4    0.5894      0.9283      0.9267
#       5    0.5656      0.9415      0.9350
#       6    0.5479      0.9506      0.9374
#       7    0.5332      0.9576      0.9352
#       8    0.5233      0.9616      0.9503
#       9    0.5125      0.9676      0.9544
#      10    0.5069      0.9692      0.9608
#      11    0.4986      0.9731      0.9575
#      12    0.4943      0.9755      0.9656
#      13    0.4893      0.9780      0.9656
#      14    0.4859      0.9793      0.9683
#      15    0.4816      0.9807      0.9691
#      16    0.4794      0.9819      0.9704
#      17    0.4797      0.9810      0.9724
#      18    0.4776      0.9819      0.9734 ⭐
#      19    0.4743      0.9843      0.9706
#      20    0.4761      0.9824      0.9708
#
#   ✅ Modèle copié vers Google Drive : /content/drive/MyDrive/best_model_finetuned.pth
# ============================================================

# %%
# ── TEST : Évaluation complète — images depuis Google Drive ───────────────────
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch.cuda.amp import autocast
import numpy as np
import time

# ── 1. MONTAGE DRIVE ───────────────────────────────────────────────────────────
from google.colab import drive

print('=' * 62)
print('📂  MONTAGE GOOGLE DRIVE')
print('=' * 62)

drive.mount('/content/drive')
print('  ✅ Drive monté')

# ── 2. CONFIG ──────────────────────────────────────────────────────────────────
# 👇 Modifier ce chemin selon ton organisation Drive
TEST_DIR   = '/content/drive/MyDrive/splitdataset/test'
MODEL_PATH = '/content/drive/MyDrive/best_model_finetuned.pth'
BATCH_SIZE = 32       # Réduit car les I/O Drive sont plus lentes
NUM_WORKERS = 2       # Réduit pour éviter les timeouts Drive

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print('\n' + '=' * 62)
print('🧪  ÉVALUATION SUR LE JEU DE TEST')
print('=' * 62)
print(f'  Device     : {device}')
print(f'  Test dir   : {TEST_DIR}')
print(f'  Modèle     : {MODEL_PATH}')
print(f'  Batch size : {BATCH_SIZE}')

# ── 3. DATASET TEST DEPUIS DRIVE ───────────────────────────────────────────────
print('\n📂  Chargement du jeu de test depuis Drive...')

test_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

test_dataset = datasets.ImageFolder(TEST_DIR, transform=test_transforms)
test_loader  = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=True
)

class_names = test_dataset.classes
num_classes = len(class_names)
print(f'  Classes ({num_classes})  : {class_names}')
print(f'  Images      : {len(test_dataset)}')
print(f'  Batches     : {len(test_loader)}')

# ── 4. CHARGEMENT DU MODÈLE DEPUIS DRIVE ──────────────────────────────────────
print('\n🧠  Chargement du modèle depuis Drive...')

model = models.mobilenet_v3_large(weights=None)
model.classifier[-1] = nn.Linear(model.classifier[-1].in_features, num_classes)
model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
model = model.to(device)
model.eval()

print(f'  ✅ Poids chargés depuis {MODEL_PATH}')

# ── 5. INFÉRENCE ───────────────────────────────────────────────────────────────
print('\n⚙️   Inférence en cours...')

all_preds  = []
all_labels = []
all_probs  = []
correct    = 0
total      = 0
t_start    = time.time()

with torch.no_grad():
    for batch_idx, (images, labels) in enumerate(test_loader):
        images = images.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        with autocast():
            outputs = model(images)

        probs  = torch.softmax(outputs, dim=1)
        preds  = outputs.argmax(1)

        correct    += (preds == labels).sum().item()
        total      += labels.size(0)
        all_preds  .extend(preds.cpu().numpy())
        all_labels .extend(labels.cpu().numpy())
        all_probs  .extend(probs.cpu().numpy())

        if (batch_idx + 1) % 5 == 0 or (batch_idx + 1) == len(test_loader):
            acc     = correct / total
            elapsed = time.time() - t_start
            print(f'    Batch {batch_idx+1:3d}/{len(test_loader)} '
                  f'| Acc : {acc:.4f} '
                  f'| Temps : {elapsed:.1f}s')

elapsed  = time.time() - t_start
test_acc = correct / total

# ── 6. RÉSULTATS GLOBAUX ───────────────────────────────────────────────────────
print('\n' + '=' * 62)
print('📊  RÉSULTATS GLOBAUX')
print('=' * 62)
print(f'  Accuracy globale : {test_acc:.4f}  ({correct}/{total})')
print(f'  Temps total      : {elapsed:.1f}s  ({total/elapsed:.0f} img/s)')

# ── 7. ACCURACY PAR CLASSE ────────────────────────────────────────────────────
print('\n📋  ACCURACY PAR CLASSE')
print(f'  {"Classe":<20} {"Correct":>8} {"Total":>8} {"Acc":>8}')
print('  ' + '-' * 48)

all_preds  = np.array(all_preds)
all_labels = np.array(all_labels)

for i, cls in enumerate(class_names):
    mask    = all_labels == i
    n_total = mask.sum()
    n_ok    = (all_preds[mask] == i).sum()
    acc_cls = n_ok / n_total if n_total > 0 else 0
    bar     = '█' * int(acc_cls * 20) + '░' * (20 - int(acc_cls * 20))
    print(f'  {cls:<20} {n_ok:>8} {n_total:>8} {acc_cls:>7.4f}  {bar}')

# ── 8. MATRICE DE CONFUSION ───────────────────────────────────────────────────
print('\n🔢  MATRICE DE CONFUSION')
print(f'  {"":>16}', end='')
for cls in class_names:
    print(f'  {cls[:8]:>8}', end='')
print()
print('  ' + '-' * (18 + 10 * num_classes))

for i, cls_true in enumerate(class_names):
    print(f'  {cls_true[:16]:<16}', end='')
    for j in range(num_classes):
        mask  = all_labels == i
        count = (all_preds[mask] == j).sum()
        marker = f'[{count:>5}]' if i == j else f' {count:>6} '
        print(f'  {marker}', end='')
    print()

# ── 9. TOP ERREURS ─────────────────────────────────────────────────────────────
print('\n❌  CONFUSIONS LES PLUS FRÉQUENTES (top 5)')
print(f'  {"Vrai":>20}  →  {"Prédit":<20}  {"Nb":>6}')
print('  ' + '-' * 54)

confusion = {}
for true, pred in zip(all_labels, all_preds):
    if true != pred:
        key = (class_names[true], class_names[pred])
        confusion[key] = confusion.get(key, 0) + 1

for (true_cls, pred_cls), count in sorted(confusion.items(), key=lambda x: -x[1])[:5]:
    print(f'  {true_cls:>20}  →  {pred_cls:<20}  {count:>6}')

print('\n' + '=' * 62)
print(f'  ✅ Test terminé — Accuracy finale : {test_acc:.4f}')
print('=' * 62)
# Out:
# ==============================================================
# 📂  MONTAGE GOOGLE DRIVE
# ==============================================================
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#   ✅ Drive monté
#
# ==============================================================
# 🧪  ÉVALUATION SUR LE JEU DE TEST
# ==============================================================
#   Device     : cuda
#   Test dir   : /content/drive/MyDrive/splitdataset/test
#   Modèle     : /content/drive/MyDrive/best_model_finetuned.pth
#   Batch size : 32
#
# 📂  Chargement du jeu de test depuis Drive...
#   Classes (6)  : ['Anthracnose', 'Ash weevil', 'Canker', 'Greening', 'Healthy', 'Leaf miner']
#   Images      : 9000
#   Batches     : 282
#
# 🧠  Chargement du modèle depuis Drive...
#   ✅ Poids chargés depuis /content/drive/MyDrive/best_model_finetuned.pth
#
# ⚙️   Inférence en cours...
# /tmp/ipykernel_4893/1558044903.py:88: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
#     Batch   5/282 | Acc : 0.9938 | Temps : 16.1s
#     Batch  10/282 | Acc : 0.9875 | Temps : 17.0s
#     Batch  15/282 | Acc : 0.9917 | Temps : 17.5s
#     Batch  20/282 | Acc : 0.9891 | Temps : 18.4s
#     Batch  25/282 | Acc : 0.9900 | Temps : 19.2s
#     Batch  30/282 | Acc : 0.9854 | Temps : 20.5s
#     Batch  35/282 | Acc : 0.9679 | Temps : 21.2s
#     Batch  40/282 | Acc : 0.9688 | Temps : 22.0s
#     Batch  45/282 | Acc : 0.9708 | Temps : 23.0s
#     Batch  50/282 | Acc : 0.9725 | Temps : 25.6s
#     Batch  55/282 | Acc : 0.9750 | Temps : 26.5s
#     Batch  60/282 | Acc : 0.9766 | Temps : 27.7s
#     Batch  65/282 | Acc : 0.9784 | Temps : 28.4s
#     Batch  70/282 | Acc : 0.9799 | Temps : 29.3s
#     Batch  75/282 | Acc : 0.9812 | Temps : 30.0s
#     Batch  80/282 | Acc : 0.9824 | Temps : 30.8s
#     Batch  85/282 | Acc : 0.9831 | Temps : 31.4s
#     Batch  90/282 | Acc : 0.9840 | Temps : 32.3s
#     Batch  95/282 | Acc : 0.9842 | Temps : 33.0s
#     Batch 100/282 | Acc : 0.9844 | Temps : 33.8s
#     Batch 105/282 | Acc : 0.9845 | Temps : 34.4s
#     Batch 110/282 | Acc : 0.9844 | Temps : 35.2s
#     Batch 115/282 | Acc : 0.9840 | Temps : 35.8s
#     Batch 120/282 | Acc : 0.9839 | Temps : 36.6s
#     Batch 125/282 | Acc : 0.9808 | Temps : 37.2s
#     Batch 130/282 | Acc : 0.9779 | Temps : 38.1s
#     Batch 135/282 | Acc : 0.9775 | Temps : 39.0s
#     Batch 140/282 | Acc : 0.9781 | Temps : 40.1s
#     Batch 145/282 | Acc : 0.9787 | Temps : 40.8s
#     Batch 150/282 | Acc : 0.9773 | Temps : 42.1s
#     Batch 155/282 | Acc : 0.9772 | Temps : 43.0s
#     Batch 160/282 | Acc : 0.9771 | Temps : 43.8s
#     Batch 165/282 | Acc : 0.9773 | Temps : 44.4s
#     Batch 170/282 | Acc : 0.9759 | Temps : 45.2s
#     Batch 175/282 | Acc : 0.9734 | Temps : 45.8s
#     Batch 180/282 | Acc : 0.9733 | Temps : 46.6s
#     Batch 185/282 | Acc : 0.9735 | Temps : 47.2s
#     Batch 190/282 | Acc : 0.9738 | Temps : 48.0s
#     Batch 195/282 | Acc : 0.9742 | Temps : 48.6s
#     Batch 200/282 | Acc : 0.9744 | Temps : 49.4s
#     Batch 205/282 | Acc : 0.9742 | Temps : 50.0s
#     Batch 210/282 | Acc : 0.9749 | Temps : 50.8s
#     Batch 215/282 | Acc : 0.9750 | Temps : 51.4s
#     Batch 220/282 | Acc : 0.9726 | Temps : 52.3s
#     Batch 225/282 | Acc : 0.9724 | Temps : 52.9s
#     Batch 230/282 | Acc : 0.9726 | Temps : 54.2s
#     Batch 235/282 | Acc : 0.9729 | Temps : 55.0s
#     Batch 240/282 | Acc : 0.9732 | Temps : 56.2s
#     Batch 245/282 | Acc : 0.9736 | Temps : 57.1s
#     Batch 250/282 | Acc : 0.9741 | Temps : 58.3s
#     Batch 255/282 | Acc : 0.9744 | Temps : 59.0s
#     Batch 260/282 | Acc : 0.9745 | Temps : 59.8s
#     Batch 265/282 | Acc : 0.9739 | Temps : 60.4s
#     Batch 270/282 | Acc : 0.9736 | Temps : 61.3s
#     Batch 275/282 | Acc : 0.9739 | Temps : 61.9s
#     Batch 280/282 | Acc : 0.9742 | Temps : 62.6s
#     Batch 282/282 | Acc : 0.9743 | Temps : 67.0s
#
# ==============================================================
# 📊  RÉSULTATS GLOBAUX
# ==============================================================
#   Accuracy globale : 0.9743  (8769/9000)
#   Temps total      : 67.1s  (134 img/s)
#
# 📋  ACCURACY PAR CLASSE
#   Classe                Correct    Total      Acc
#   ------------------------------------------------
#   Anthracnose              1456     1500  0.9707  ███████████████████░
#   Ash weevil               1497     1500  0.9980  ███████████████████░
#   Canker                   1449     1500  0.9660  ███████████████████░
#   Greening                 1439     1500  0.9593  ███████████████████░
#   Healthy                  1456     1500  0.9707  ███████████████████░
#   Leaf miner               1472     1500  0.9813  ███████████████████░
#
# 🔢  MATRICE DE CONFUSION
#                     Anthracn  Ash weev    Canker  Greening   Healthy  Leaf min
#   ------------------------------------------------------------------------------
#   Anthracnose       [ 1456]        0         7        24         3        10
#   Ash weevil              0   [ 1497]        0         2         1         0
#   Canker                 22         9   [ 1449]       11         2         7
#   Greening               13         0         5   [ 1439]       41         2
#   Healthy                10         2         1        31   [ 1456]        0
#   Leaf miner              4         2         2        18         2   [ 1472]
#
# ❌  CONFUSIONS LES PLUS FRÉQUENTES (top 5)
#                   Vrai  →  Prédit                    Nb
#   ------------------------------------------------------
#               Greening  →  Healthy                   41
#                Healthy  →  Greening                  31
#            Anthracnose  →  Greening                  24
#                 Canker  →  Anthracnose               22
#             Leaf miner  →  Greening                  18
#
# ==============================================================
#   ✅ Test terminé — Accuracy finale : 0.9743
# ==============================================================
